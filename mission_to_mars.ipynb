# %%
# Import dependencies

from bs4 import BeautifulSoup as soup
from splinter import Browser
import pandas as pd
import aux_func as aux

# initialize splinter browser
browser = Browser('chrome', 
                  **{"executable_path": "/usr/local/bin/chromedriver"}, 
                  headless=False)

# %%
# Scrape NASA Mars site for headlines, dates, and content preview

url = 'https://mars.nasa.gov/news/'
webpage = aux.getParsedWebpage(browser, url)

# Scrapes most recent headlines, date, and text in order
headlines_grouped = soup.find_all(webpage, 'h3', class_=None)
dates_grouped = soup.find_all(webpage, 'div', class_='list_date')
text_grouped = soup.find_all(webpage, 'div', class_='article_teaser_body')

# Iterates and generates list of all items
zipped_headlines = list(zip(aux.getParsedTextList(headlines_grouped),
                            aux.getParsedTextList(dates_grouped),
                            aux.getParsedTextList(text_grouped)))

# Generate Dataframe from raw data
headline_df = pd.DataFrame(zipped_headlines)
headline_df.rename(columns={0:'headline', 
                            1:'date', 
                            2:'text'}, 
                   inplace=True)
headline_df
# Out:
#                                              headline                date  \
# 0       Curiosity Surveys a Mystery Under Dusty Skies  September  6, 2018
# 1       Martian Skies Clearing over Opportunity Rover     August 30, 2018
# 2           NASA's InSight Has a Thermometer for Mars     August 28, 2018
# 3   Digital Creators: Apply for NASA Mars Landing ...     August 24, 2018
# 4   NASA's InSight Passes Halfway to Mars, Instrum...     August 20, 2018
# 5     Six Things About Opportunity's Recovery Efforts     August 16, 2018
# 6   Meet the People Behind NASA's InSight Mars Lander     August  2, 2018
# 7   Mars Terraforming Not Possible Using Present-D...       July 30, 2018
# 8          Opportunity Hunkers Down During Dust Storm       July 26, 2018
# 9   NASA Statement on Possible Subsurface Lake nea...       July 25, 2018
# 10  JPL's 'Martians' Are Coming to Griffith Observ...       July 25, 2018
# 11  NASA's MAVEN Spacecraft Finds That 'Stolen' El...       July 23, 2018
# 12  'Storm Chasers' on Mars Searching for Dusty Se...       July 19, 2018
# 13   NASA Mars Mission Adds Southern California Dates       June 26, 2018
# 14       Curiosity Captures Photos of Thickening Dust       June 20, 2018
# 15      NASA Encounters the Perfect Storm for Science       June 13, 2018
# 16   Media Telecon About Mars Dust Storm, Opportunity       June 12, 2018
# 17  NASA Finds Ancient Organic Material, Mysteriou...       June  7, 2018
# 18  NASA to Host Live Discussion on New Mars Scien...       June  6, 2018
# 19           Mars Curiosity's Labs Are Back in Action       June  4, 2018
# 20                    NASA CubeSats Steer Toward Mars       June  1, 2018
# 21  Scientists Shrink Chemistry Lab to Seek Eviden...       June  1, 2018
# 22                         InSight Steers Toward Mars        May 23, 2018
# 23  Drilling Success: Curiosity is Collecting Mars...        May 23, 2018
# 24  NASA's Curiosity Rover Aims to Get Its Rhythm ...        May 17, 2018
# 25              A Pale Blue Dot, As Seen by a CubeSat        May 15, 2018
# 26  Mars Helicopter to Fly on NASA’s Next Red Plan...        May 11, 2018
# 27      NASA's First Deep-Space CubeSats Say: 'Polo!'        May  5, 2018
# 28  NASA, ULA Launch Mission to Study How Mars Was...        May  5, 2018
# 29  NASA’s First Mission to Study the Interior of ...        May  3, 2018
# 30  Vice President Pence Visits JPL, Previews NASA...      April 30, 2018
# 31  NASA Sets Sights on May 5 Launch of InSight to...      April 27, 2018
# 32                     Results of Heat Shield Testing      April 26, 2018
# 33     NASA Engineers Dream Big with Small Spacecraft      April 19, 2018
# 34  Bound for Mars: Countdown to First Interplanet...      April  6, 2018
# 35              NASA Invests in Visionary Technology       March 30, 2018
# 36           NASA is Ready to Study the Heart of Mars      March 29, 2018
# 37      ‘Marsquakes’ Could Shake Up Planetary Science      March 28, 2018
# 38                Mars Curiosity Celebrates Sol 2,000      March 22, 2018
# 39  NASA Briefing on First Mission to Study Mars I...      March 22, 2018
#
#                                                  text
# 0   NASA's Curiosity rover surveyed its surroundin...
# 1   Clearing skies allow Opportunity rover enginee...
# 2   The mission's heat probe could reveal how the ...
# 3   Up to 30 multimedia participants will be selec...
# 4   NASA's InSight spacecraft, en route to a Nov. ...
# 5   The global dust storm on Mars could soon let i...
# 6   A series of NASA videos highlight scientists a...
# 7   Transforming the inhospitable Martian environm...
# 8   It's the beginning of the end for the planet-e...
# 9   A new paper suggests that liquid water may be ...
# 10  On July 30, when Mars and Earth are closer tha...
# 11  Auroras appear on Earth as ghostly displays of...
# 12  Scientists with NASA's Mars orbiters have been...
# 13  Looking for summer fun? Southern California fa...
# 14  A storm of tiny dust particles has engulfed mu...
# 15  One of the most intense Martian dust storms ev...
# 16  NASA will host a media telecon on Wednesday, J...
# 17  NASA’s Curiosity rover has found evidence on M...
# 18  Questions are welcome during a live discussion...
# 19  NASA's Curiosity rover is analyzing drilled sa...
# 20  NASA has achieved a first for the class of tin...
# 21  An international team of scientists has create...
# 22  The spacecraft has completed its first traject...
# 23  Engineers will now test delivering samples to ...
# 24  Rover engineers at JPL will try to restore per...
# 25  One of NASA's MarCO CubeSats has taken its fir...
# 26  NASA is adding a Mars helicopter to the agency...
# 27  MarCO is a pair of tiny spacecraft that launch...
# 28  NASA’s Mars InSight mission launched this morn...
# 29  All systems are go for NASA’s next launch to t...
# 30  A week before NASA's next Mars launch, Vice Pr...
# 31  NASA’s next mission to Mars, InSight, is sched...
# 32  A post-test inspection of the composite struct...
# 33  The first CubeSat mission to deep space will l...
# 34  On May 5, millions of Californians may witness...
# 35  NASA is investing in technology concepts, incl...
# 36  NASA is about to go on a journey to study the ...
# 37  InSight, the next mission to the Red Planet, w...
# 38  NASA's Mars Curiosity rover just hit a new mil...
# 39  NASA’s next mission to Mars will be the topic ...

# %%
# Possible the page is uploading an outdated version of the website because
# the Splinter browser is pulling outdated version?

# Scrape JPL Mars website for most recent image
# For some reason this pulls an image of Neptune

url = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
webpage = aux.getParsedWebpage(browser, url)

# Get title and description

featured_title = soup.find(webpage, 'h1', class_='media_feature_title').get_text()
featured_description = soup.find(webpage, 'a', class_='button fancybox').get('data-description')

# 
featured_url = soup.find(webpage, 'a', class_='button fancybox').get('data-fancybox-href')

featured_url=f'https://www.jpl.nasa.gov{featured_url}'

print(featured_title)
print(featured_description)
print(featured_url)
# Out:
# 				  Bright Penelope
# NASA's Cassini spacecraft looks down on the north of Tethys and sees brightly illuminated Penelope Crater on the trailing hemisphere of the moon in this image taken on July 27, 2009.
# https://www.jpl.nasa.gov/spaceimages/images/mediumsize/PIA11591_ip.jpg

# %%
#Mars Twitter Parse

#Hardcoded a single tweet for now for testing (not all tweets are weather reports, causes errors)
url = 'https://twitter.com/MarsWxReport/status/1038219633726316544'
webpage = aux.getParsedWebpage(browser, url)

#std_tweet_class = 'TweetTextSize TweetTextSize--normal js-tweet-text tweet-text'
std_tweet_class = 'TweetTextSize TweetTextSize--jumbo js-tweet-text tweet-text'

# pull text of most recent tweet about the weather
mars_weather = soup.find_all(webpage, 'p', class_= std_tweet_class)[0].get_text()

# create split string to pull apart and add to dataframe
mars_weather_split = recent_weather.split(',')

# create dictionary to turn into a dataframe
weather_dict = {'mars_date':f'{mars_weather.split("(")[0]}',
                'earth_date':f'{mars_weather.split("(")[1].split(")")[0]}',
                'temp_high':f'{mars_weather_split[1].split(" ")[2]}',
                'temp_low':f'{mars_weather_split[2].split(" ")[2]}',
                'pressure':f'{mars_weather_split[3].split(" ")[3]}',
                'daylight':f'{mars_weather_split[4].split(" ")[2]}'}
weather_df = pd.DataFrame.from_dict(weather_dict, orient='index')
weather_df = weather_df.rename(columns={0:'Most Recent Weather on Mars'})
weather_df
# Out:
#            Most Recent Weather on Mars
# mars_date                    Sol 2162
# earth_date                  2018-09-05
# temp_high                      -5C/23F
# temp_low                     -69C/-92F
# pressure                          8.85
# daylight                   05:37-17:53

# %%
# Mars Facts

url = 'https://space-facts.com/mars/'
webpage = aux.getParsedWebpage(browser, url)

# dictionary to hold facts
facts_dict = {}

# get rows in facts table, parse into dictionary
facts_all = soup.find(webpage, 
                      'table', 
                      class_='tablepress tablepress-id-mars').find_all('tr')
for fact in facts_all:
    facts_dict[soup.find(fact, 'strong').get_text()] = (soup.find(fact, class_='column-2').get_text())

# convert fact_dict to DF and HTML
facts_df = pd.DataFrame.from_dict(facts_dict, orient='index')
facts_df.rename(columns={0:'Facts about Mars'}, inplace=True)
facts_html = pd.DataFrame.to_html(facts_df)

facts_df
# Out:
#                                     Facts about Mars
# Equatorial Diameter:                      6,792 km\n
# Polar Diameter:                           6,752 km\n
# Mass:                  6.42 x 10^23 kg (10.7% Earth)
# Moons:                           2 (Phobos & Deimos)
# Orbit Distance:             227,943,824 km (1.52 AU)
# Orbit Period:                 687 days (1.9 years)\n
# Surface Temperature:                   -153 to 20 °C
# First Record:                      2nd millennium BC
# Recorded By:                    Egyptian astronomers

# %%
# Mars Hemispheres

url = 'https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars'
webpage = aux.getParsedWebpage(browser, url)

base_url = 'https://astrogeology.usgs.gov/'

# get all unique links to photo pages
page_links_list = []
page_links = soup.find_all(webpage, 'a', class_='itemLink product-item')
[page_links_list.append(page.get('href')) for page in page_links]
page_links_list = list(set(page_links_list))

image_list = []

# iterate through links and pull image URLs
for link in page_links_list:
    url = f'https://astrogeology.usgs.gov{link}'
    webpage = aux.getParsedWebpage(browser, url)
    
    # get image title
    title = soup.find(webpage, 'h2', class_='title').get_text()
    
    # get full size image link
    downloads_section = soup.find(webpage, 'div', class_='downloads')
    image_link = soup.find(downloads_section, 'a').get('href')
    
    # add title and full-size image url to dict
    image_list.append({'title':title,
                       'image_url':image_link})

# create DF
image_df = pd.DataFrame(image_list, columns=['title', 'image_url'])
image_df
# Out:
#                                   title  \
# 0  Valles Marineris Hemisphere Enhanced
# 1      Schiaparelli Hemisphere Enhanced
# 2          Cerberus Hemisphere Enhanced
# 3      Syrtis Major Hemisphere Enhanced
#
#                                            image_url
# 0  http://astropedia.astrogeology.usgs.gov/downlo...
# 1  http://astropedia.astrogeology.usgs.gov/downlo...
# 2  http://astropedia.astrogeology.usgs.gov/downlo...
# 3  http://astropedia.astrogeology.usgs.gov/downlo...

# %%
# Out:
# 'Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53'

# %%
# Out:
# ['Sol 2162 (2018-09-05)',
#  ' high -5C/23F',
#  ' low -69C/-92F',
#  ' pressure at 8.85 hPa',
#  ' daylight 05:37-17:53']

# %%
# Out:
# ['', 'daylight', '05:37-17:53']
